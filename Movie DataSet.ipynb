# %%
# import libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading csv file

df = pd.read_csv("Movie Dataset\movies.csv")

# %%
# overview of dataset

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# checking the null values

df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
# data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# droping duplicates values

df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# droping Null values

df.dropna(inplace=True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# spliting the relased cloumn 

new= df["released"].str.split("(",n=1,expand=True)

# %%
df ["releaseddate"] = new[0]

# %%
# view of data set
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# checking new column
new= df["releaseddate"].str.split(",",n=1,expand=True)

# %%
new
# Out:
#                 0       1
# 0         June 13   1980
# 1          July 2   1980
# 2         June 20   1980
# 3          July 2   1980
# 4         July 25   1980
# ...           ...     ...
# 7648   January 17   2020
# 7649  February 14   2020
# 7650   January 17   2020
# 7651  February 21   2020
# 7652    August 28   2020
#
# [5421 rows x 2 columns]

# %%
# adding new column in the dataset
df["Year_correct"]= new[1]

# %%
# viewing dataset
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
new= df["released"].str.split("(",n=1,expand=True)

# %%
new
# Out:
#                        0               1
# 0         June 13, 1980   United States)
# 1          July 2, 1980   United States)
# 2         June 20, 1980   United States)
# 3          July 2, 1980   United States)
# 4         July 25, 1980   United States)
# ...                  ...             ...
# 7648   January 17, 2020   United States)
# 7649  February 14, 2020   United States)
# 7650   January 17, 2020   United States)
# 7651  February 21, 2020   United States)
# 7652    August 28, 2020   United States)
#
# [5421 rows x 2 columns]

# %%
df["released"] = new[0]

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year            released  score      votes         director  \
# ...

# %%
df["released"] = pd.to_datetime(df['released'])

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year   released  score      votes         director  \
# ...

# %%
# changing data types of the the columns

df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')

# %%
# sorting the data set
df.sort_values(by=["gross"], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#        released  score    votes             director                   writer  \
# ...

# %%
# droping the duplicate column

df.drop(['year'], axis=1, inplace=True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
# createing new dataframe of clean dataset
newdf = df

# %%
newdf
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
newdf.describe()
# Out:
#              score         votes        budget         gross      runtime
# count  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03  5421.000000
# mean      6.392455  1.150661e+05  3.600917e+07  1.032297e+08   108.152739
# std       0.962730  1.844073e+05  4.157337e+07  1.873027e+08    18.115698
# min       1.900000  1.950000e+02  6.000000e+03  3.090000e+02    63.000000
# 25%       5.800000  1.900000e+04  1.000000e+07  1.073640e+07    95.000000
# 50%       6.500000  5.200000e+04  2.180000e+07  3.686941e+07   105.000000
# 75%       7.100000  1.290000e+05  4.500000e+07  1.124625e+08   118.000000
# max       9.300000  2.400000e+06  3.560000e+08  2.847246e+09   271.000000

# %%
plt.scatter(x=df["budget"],y=df["gross"])
plt.title("Budget vs Gross Earning")
plt.xlabel("Gross Earning")
plt.ylabel("Budget for Film")
# Out:
# Text(0, 0.5, 'Budget for Film')

# %%
sns.regplot(data = newdf, x="budget", y="gross", line_kws={"color": "red"})
plt.title("Budget vs Gross Earning")
plt.xlabel("Gross Earning")
plt.ylabel("Budget for Film")
# Out:
# Text(0, 0.5, 'Budget for Film')

# %%
sns.pairplot(data=newdf)

# %%
sns.countplot(data= newdf, x='rating')
plt.xticks(rotation=45)
plt.title("Total Rating as per Movies")
plt.xlabel("Rating")
# Out:
# Text(0.5, 0, 'Rating')

# %%
sns.kdeplot(data= newdf, x='budget',fill=True,color="purple")
plt.title("Density as per Budget of Movies")
# Out:
# Text(0.5, 1.0, 'Density as per Budget of Movies')

# %%
sns.countplot(data= newdf,x='genre')
plt.xticks(rotation=50)
plt.title("Total movies as per Genre")
plt.xlabel("genre")
# Out:
# Text(0.5, 0, 'genre')

# %%
sns.barplot(data= newdf,x='genre',y ='gross')
plt.xticks(rotation=50)
plt.title("Gross income as per Movies Genre")
plt.xlabel("genre")
plt.ylabel("budget")
# Out:
# Text(0, 0.5, 'budget')

# %%
sns.barplot(data= newdf,x='genre',y ='budget')
plt.xticks(rotation=50)
plt.title("Budget as per Movies Genre")
plt.xlabel("genre")
plt.ylabel("budget")
# Out:
# Text(0, 0.5, 'budget')

# %%
plt.scatter(x=newdf['score'], y=newdf['budget'])
plt.title("Score as per Budget")
plt.xlabel("score")
plt.ylabel("budget")
# Out:
# Text(0, 0.5, 'budget')

# %%
newdf.corr(method="pearson")
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
corrrelation = newdf.corr(method="pearson")
sns.heatmap(corrrelation,annot=True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
# Out:
# Text(50.722222222222214, 0.5, 'Movie Features')
